# %% [markdown]
# # Test Notebook
#
# A simple notebook for testing Python execution.

# %%
import sys
print(f"Jupyter Kernel running from: {sys.executable}")
# Out:
# Jupyter Kernel running from: c:\Users\15132\OneDrive\Desktop\course-project\First-GitHub\notes\.venv-1\Scripts\python.exe

# %%
print("Notebook is working!")
# Out:
# Notebook is working!
